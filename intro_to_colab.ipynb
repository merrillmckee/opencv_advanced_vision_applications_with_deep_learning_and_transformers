# %% [markdown]
# <a href="https://colab.research.google.com/github/merrillmckee/opencv_advanced_vision_applications_with_deep_learning_and_transformers/blob/main/intro_to_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %%
import numpy as np
import keras
import tensorflow
import cv2
import matplotlib.pyplot as plt

print(cv2.__version__)
print(keras.__version__)
# Out:
# 4.12.0
# 3.10.0

# %%
# !pip install opencv-contrib-python

# %%
# %%bash
# apt-get install caffe-cuda

# %%
# %%bash
# ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# pip install gputil
# pip install psutil
# pip install humanize
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=4df83a151f8a3d2b38214e77c07f022e9753a9884fa7e827dc9d719d2d9e5d58
#   Stored in directory: /root/.cache/pip/wheels/92/a8/b7/d8a067c31a74de9ca252bbe53dea5f896faabd25d55f541037
# Successfully built gputil
# ...

# %%
import psutil
import humanize
import os
import GPUtil as GPU

# %%
GPUs = GPU.getGPUs()
gpu = GPUs[0]
print(len(GPUs))
# Out:
# 1

# %%
print(f'GPU RAM Free: {gpu.memoryFree:.0f}MB | Used: {gpu.memoryUsed:.0f}MB | Util {gpu.memoryUtil*100:3.0f}% | Total {gpu.memoryTotal:.0f}MB')
# Out:
# GPU RAM Free: 15095MB | Used: 0MB | Util   0% | Total 15360MB

# %%
print(f'Get RAM free: {humanize.naturalsize(psutil.virtual_memory().available)}')
# Out:
# Get RAM free: 11.7 GB

# %%
process = psutil.Process(os.getpid())
print(humanize.naturalsize(process.memory_info().rss))
# Out:
# 880.6 MB

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         113G   39G   75G  35% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  750M  62% /usr/sbin/docker-init
# /dev/sda1        74G   41G   33G  56% /kaggle/input
# tmpfs           6.4G  3.7M  6.4G   1% /var/colab
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded:
  print(f'User uploaded file {fn} with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-874ebb6f-113a-4f16-a4a5-cf4c2e88aa44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-874ebb6f-113a-4f16-a4a5-cf4c2e88aa44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# R.jpg  sample_data

# %%
import cv2
im = cv2.imread('R.jpg')
imRGB = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(imRGB)
